# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
ruta = '/content/drive/MyDrive/Colab Notebooks/231102-1_machine_learning_regresion_lineal_correlaciones/modelo_consumo_cerveza'
modelo = open(ruta,'rb')
lm_new = pickle.load(modelo)
modelo.close()

temp_max = 30.5
lluvia = 12.2
fds = 0
entrada = [[temp_max, lluvia, fds]]
print('{0:.2f} litros'.format(lm_new.predict(entrada)[0]))
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-9-b0295e8eea74> in <cell line: 4>()
#       2 ruta = '/content/drive/MyDrive/Colab Notebooks/231102-1_machine_learning_regresion_lineal_correlaciones/modelo_consumo_cerveza'
#       3 modelo = open(ruta,'rb')
# ----> 4 lm_new = pickle.load(modelo)
#       5 modelo.close()
#       6
#
# EOFError: Ran out of input
